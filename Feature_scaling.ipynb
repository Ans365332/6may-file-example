# %% [markdown]
# <a href="https://colab.research.google.com/github/Ans365332/6may-file-example/blob/main/Feature_scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Min-Max scaling(Normalization)
# implemantation of min max scaling
#
# min=0 max=1

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
li=[10,20,30,40,50]
scaler=MinMaxScaler()
transformed_data= scaler.fit_transform([[10],[20],[30],[40],[50]] )

# Fit and transform?
# Fit in min max-> find min=10 max=50 --> after finding the
# mean and max it start calculating min max scaling

# Transform--> start applying into the data

# %%
print(transformed_data)
# Out:
# [[0.  ]
#  [0.25]
#  [0.5 ]
#  [0.75]
#  [1.  ]]

# %% [markdown]
# # 2.Standarization
# implementation of satndard score scaling
#
# mean=0 std=1

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
stdscaler=StandardScaler()
scaled=stdscaler.fit_transform([[10],[20],[30],[40],[50]])

# %%
print(scaled)
# Out:
# [[-1.41421356]
#  [-0.70710678]
#  [ 0.        ]
#  [ 0.70710678]
#  [ 1.41421356]]

# %%
from sklearn.preprocessing import OrdinalEncoder
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/loan_data - loan_data.csv')
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71948
# 1              21        female      High School          12282
# 2              25        female      High School          12438
# 3              23        female         Bachelor          79753
# 4              24          male           Master          66135
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47971
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56942
# 44998          29          male         Bachelor          33164
# 44999          24          male      High School          51609
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT      35000           PERSONAL
# ...

# %%
# Target and independent variable

# independent variale --> the features or the variables which do not
# dependent on any other features

# Target variable or target column

X=df.drop(columns=['loan_status'])
y=df['loan_status']

# %%
X
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71948
# 1              21        female      High School          12282
# 2              25        female      High School          12438
# 3              23        female         Bachelor          79753
# 4              24          male           Master          66135
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47971
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56942
# 44998          29          male         Bachelor          33164
# 44999          24          male      High School          51609
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT      35000           PERSONAL
# ...

# %%
y
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 44995    1
# 44996    1
# 44997    1
# 44998    1
# 44999    1
# Name: loan_status, Length: 45000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
df.shape
# Out:
# (45000, 14)

# %%
X_train.shape
# Out:
# (36000, 13)

# %%
X_test.shape
# Out:
# (9000, 13)

# %%
y_test.shape
# Out:
# (9000,)

# %%
y_train.shape
# Out:
# (36000,)
