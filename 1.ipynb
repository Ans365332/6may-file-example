# %% [markdown]
# <a href="https://colab.research.google.com/github/Ans365332/6may-file-example/blob/main/1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/event.csv')
df
# Out:
#     id            event_name                email  guests   budget  days  \
# 0    1      Wedding Ceremony      rahul@gmail.com     300   500000     3
# 1    2        Birthday Party       neha@yahoo.com      50    60000     1
# 2    3     Corporate Meeting     amit@company.com     120   200000     2
# 3    4         Music Concert      rohan@gmail.com     800  1200000     2
# 4    5  Festival Celebration      pooja@gmail.com     500   700000     4
# 5    6      Wedding Ceremony     sunita@gmail.com     250   450000     3
# 6    7     Corporate Meeting      hr@techcorp.com      80   150000     1
# 7    8        Birthday Party       anil@gmail.com      40    40000     1
# 8    9         Music Concert     events@music.com    1000  2000000     3
# 9   10  Festival Celebration  organizer@gmail.com     600   900000     5
# 10  11      Wedding Ceremony     deepak@gmail.com     200   380000     2
# 11  12     Corporate Meeting      manager@biz.com      60   100000     1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['event_name']=le.fit_transform(df['event_name'])
df['catering']=le.fit_transform(df['catering'])

# %%
x=df.drop(['catering'],axis=1)
y=df['catering']

# %%
x=x.drop(['email'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -0.9769063021516156
