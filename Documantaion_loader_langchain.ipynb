# %% [markdown]
# <a href="https://colab.research.google.com/github/Ans365332/6may-file-example/blob/main/Documantaion_loader_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U langchain langchain-community

# %%
# !pip install langchain_community

# %%
# Txt data loading
from langchain_community.document_loaders import TextLoader

loader = TextLoader("/content/be-good.txt")
loaded_data = loader.load()
# Out:
# /tmp/ipykernel_8083/3695050289.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
#loaded_data

# %%
# CSVloader

from langchain_community.document_loaders import CSVLoader

loader = CSVLoader("/content/Street_Tree_List.csv")
loaded_data = loader.load()

# %%
# loaded_data

# %%
# !pip install unstructured

# %%
# HTML data

from langchain_community.document_loaders import UnstructuredHTMLLoader

loader = UnstructuredHTMLLoader("/content/100-startups.html")
loaded_data = loader.load()

# %%
# loaded_data

# %%
# Pdf data

from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader('/content/5pages.pdf')

loaded_data = loader.load_and_split()
# loaded_data

# %%
# loaded_data

# %%
 loaded_data[0].page_content
# Out:
# 'Page 1 of 4 \nPDF Files \nScan – Create – Reduce File Size  \n \n \nIt is recommended that you purchase an Adobe Acrobat product that \nallows you to read, create and manipulate PDF documents.  Go to \nhttp://www.adobe.com/products/acrobat/matrix.html\n to compare \nAdobe products and features –Adobe Acrobat Standard is sufficient. \n \n \nScanning Documents \n \nYou should only have to scan documents that are not electronic, and \nwhen you are unable to create a PDF using PDFMaker or the Print \nCommand from the application you are using.   \n \nSignature Pages \nIf you have a document such as a CV that requires a signature on a \npage only print the page that requires the signature –printing the \nentire document and scanning it is not\n necessary or desired.  Once you \nsign and scan the signature page you can combine it with the original \ndocument using the Create PDF From Multiple Files feature. \n \nScanner Settings \nBefore scanning documents remember to make certain that th
# ...

# %%
# !pip install wikipedia

# %%
# wikipedia data loader

from langchain_community.document_loaders import WikipediaLoader

loader = WikipediaLoader(query="TATA", load_max_docs=1)

loaded_data = loader.load()[0].page_content
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#    1115         try:
# -> 1116             return complexjson.loads(self.text, **kwargs)
#    1117         except JSONDecodeError as e:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, array_hook, **kw)
#     516             and not use_decimal and not allow_nan and not kw):
# --> 517         return _default_decoder.decode(s)
#     518     if cls is None:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     395             s = str(s, self.encoding)
# --> 396         obj, end = self.raw_decode(s)
#     397         end = _w(s, end).end()
#
# ...

# %%
# !pip install -U langchain langchain-community wikipedia

# %%
loader = WikipediaLoader(query="TATA", load_max_docs=1)

# %%
loader = WikipediaLoader(
    query="Tata Group",
    load_max_docs=1
)

docs = loader.load()

print(docs[0].page_content)

# %%
from langchain_community.document_loaders import WikipediaLoader

try:
    loader = WikipediaLoader(query="Tata Group", load_max_docs=1)
    docs = loader.load()
    print(docs[0].page_content)
except Exception as e:
    print(type(e))
    print(e)

# %%
import langchain
import langchain_community
import wikipedia

print(langchain.__version__)
print(langchain_community.__version__)
print(wikipedia.__version__)

# %%
import wikipedia

text = wikipedia.page("Tata Group").content

print(text[:1000])

# %%
from langchain_community.document_loaders import WikipediaLoader

loader = WikipediaLoader(query="TATA", load_max_docs=1)
loaded_data = loader.load()[0].page_content

# %%
# !pip uninstall wikipedia -y
# !pip install wikipedia
# !pip install -U langchain-community

# %%
# !pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.7/25.7 MB 41.0 MB/s eta 0:00:00
# ...

# %%
# !pip install arxiv

# %%
from langchain_community.document_loaders import ArxivLoader

loader = ArxivLoader(
    query="transformer models",
    load_max_docs=1
)

docs = loader.load()

print(docs[0].page_content[:1000])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8083/1304962628.py in <cell line: 0>()
#       6 )
#       7
# ----> 8 docs = loader.load()
#       9
#      10 print(docs[0].page_content[:1000])
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/document_loaders/base.py in load(self)
#      41             The documents.
#      42         """
# ---> 43         return list(self.lazy_load())
#      44
#      45     async def aload(self) -> list[Document]:
#
# /usr/local/lib/python3.12/dist-packages/langchain_community/document_loaders/arxiv.py in lazy_load(self)
#     147     def lazy_load(self) -> Iterator[Document]:
#     148         """Lazy load Arvix documents"""
# --> 149         yield from self.client.lazy_load(self.query)
#     150
#     151     def get_summaries_as_docs(self) -> List[Document]:
#
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(
    "https://en.wikipedia.org/wiki/Tata_Group"
)

docs = loader.load()

print(docs[0].page_content[:1000])
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# Tata Group - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload fileSpecial pages
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
#
# Donate
#
#
# Create account
#
#
# Log in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# History
#
#
#
#
# Toggle History subsection
#
#
#
#
#
# 1.1
# ...
