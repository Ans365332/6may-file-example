# %% [markdown]
# <a href="https://colab.research.google.com/github/Ans365332/6may-file-example/blob/main/Fasttext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 1.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pybind11-3.0.4-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached pybind11-3.0.4-py3-none-any.whl (314 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp312-cp312-linux_x86_64.whl size=4653910 sha256=81941d03de31e2b38362fbdb1b2a730d327b66b68560376b8a62a66bc1469851
#   Stored in directory: /root/.cache/pip/wheels/20/27/95/a7baf1b435f1cbde017cabdf1e9688526d2b0e929255a359c6
# Successfully built fasttext
# ...

# %%
import fasttext

# %%
paragraph = """
Artificial intelligence is transforming the world.
Machine learning helps computers learn from data.
Deep learning is a part of machine learning.
FastText is a useful library for NLP tasks.
"""

with open('paragraph.txt', 'w') as f:
    f.write(paragraph)

# %%
model = fasttext.train_unsupervised('paragraph.txt',model = "skipgram")

# %%
print(model.get_word_vector("machine"))
# Out:
# [ 8.1811886e-05  3.7517873e-04  5.6723674e-04 -5.3487648e-04
#   1.7060636e-04  3.4931887e-04  5.2740623e-04  2.7336302e-04
#  -3.2303750e-04  3.2573770e-04  4.5847610e-05  1.7622410e-04
#   1.6139864e-05 -3.9019799e-04 -2.4998229e-04 -5.8769376e-05
#  -7.5240961e-05  2.5438462e-04  1.1126072e-03 -5.2877510e-04
#   1.3602396e-03 -2.2216239e-04 -4.5304823e-05  5.0364499e-05
#  -1.0998168e-03 -2.6891110e-04  5.0525926e-04 -1.0117027e-04
#  -2.3246810e-04 -8.3611958e-04  3.3943658e-04 -6.3759566e-04
#   6.3348294e-04 -2.0519242e-04 -1.1069955e-04 -7.9945824e-04
#   4.7523639e-04  9.1401125e-05 -3.6329959e-04  3.2377942e-04
#   2.0558735e-04  1.9708247e-04  1.0612421e-06 -3.3414611e-04
#   3.1215372e-05 -6.6138507e-04 -3.7588942e-04 -1.9545201e-05
#   2.5407400e-04  5.8538129e-04  8.5859833e-04  1.2271898e-03
#   2.9517149e-04 -2.1208575e-04  2.0074609e-04  4.9416663e-04
#  -1.3835770e-03  2.9795291e-04  1.8344645e-04 -1.4823201e-04
# ...

# %%
print(model.get_nearest_neighbors("machine"))
# Out:
# [(0.06931550800800323, '</s>')]

# %%
model.get_words()
# Out:
# ['</s>']

# %%
text = """
Artificial intelligence is transforming the modern world.
Machine learning helps computers learn from data automatically.
Deep learning is a powerful technique based on neural networks.
Natural language processing enables machines to understand human language.
FastText is a library developed by Facebook for word embeddings.
Word embeddings convert text into numerical vectors.
Data science combines statistics and programming skills.
Python is widely used in machine learning and data science.
Artificial intelligence is used in healthcare for disease prediction.
Machine learning improves recommendation systems in e-commerce.
Deep learning is used in image recognition and computer vision.
Natural language processing powers chatbots and virtual assistants.
FastText handles rare words using subword information.
Word vectors capture semantic meaning of words.
Big data is growing rapidly in modern industries.
Data preprocessing is an important step in machine learning.
Cleaning data improves model accuracy significantly.
Feature engineering helps improve machine learning models.
Supervised learning uses labeled data for training.
Unsupervised learning finds patterns in unlabeled data.
Reinforcement learning learns through rewards and penalties.
Neural networks are inspired by the human brain.
Backpropagation is used to train deep learning models.
Gradient descent helps minimize errors in models.
AI is used in self-driving car technology.
Speech recognition converts voice into text.
Image processing helps detect objects in images.
Recommendation systems suggest products to users.
Search engines use machine learning for ranking results.
Data visualization helps understand complex datasets.
Python libraries simplify machine learning tasks.
NumPy is used for numerical computations in Python.
Pandas is used for data manipulation and analysis.
Scikit-learn provides machine learning algorithms.
FastText is efficient for large text datasets.
Word embeddings improve natural language understanding.
Text classification is used in spam detection.
Sentiment analysis detects emotions in text.
AI helps automate repetitive tasks in industries.
Machine learning models require training and testing data.
Overfitting occurs when a model learns noise in data.
Underfitting occurs when a model is too simple.
Cross-validation helps evaluate model performance.
Accuracy measures how correct a model is.
Precision and recall are important evaluation metrics.
Data science is useful in business decision making.
Healthcare uses AI for medical diagnosis.
Finance uses machine learning for fraud detection.
Education uses AI for personalized learning.
E-commerce uses AI for customer recommendations.
Cloud computing supports large-scale AI systems.
Algorithms are step-by-step instructions for solving problems.
Programming is essential for building AI models.
FastText creates vector representations of words.
Subword modeling improves handling of rare words.
Natural language understanding is a part of NLP.
Chatbots use NLP to interact with users.
Virtual assistants like Siri use AI technologies.
Machine learning is evolving rapidly every year.
Deep learning requires large amounts of data.
Training data quality affects model performance.
Data labeling is important for supervised learning.
Feature selection improves model efficiency.
Model evaluation ensures reliability of predictions.
AI systems can learn from experience.
Data is the foundation of machine learning.
Statistics helps in understanding data distributions.
Probability is used in predictive modeling.
Linear regression is a basic machine learning algorithm.
Classification predicts categories of data.
Clustering groups similar data points together.
Decision trees are used for classification problems.
Random forest improves accuracy using multiple trees.
Support vector machines separate data using hyperplanes.
K-means is a popular clustering algorithm.
Machine learning models can be deployed in production.
APIs help integrate AI models into applications.
Deep learning frameworks include TensorFlow and PyTorch.
GPU accelerates deep learning training.
Natural language processing includes tokenization and stemming.
Stopwords are removed during text preprocessing.
Lemmatization reduces words to their base form.
Tokenization splits text into smaller units.
AI is used in robotics for automation.
Self-learning systems improve over time.
Machine learning helps detect anomalies in data.
Fraud detection systems protect financial transactions.
AI is shaping the future of technology.
Innovation in AI is growing very fast.
FastText improves text representation quality.
Word similarity helps find related terms.
Embedding space represents meaning of words.
Semantic relationships connect related concepts.
Machine learning is used in weather prediction.
AI helps in traffic management systems.
Smart assistants understand user commands.
Data-driven decisions improve business outcomes.
"""

with open("para.txt", "w") as f:
    f.write(text)

# %%
data = fasttext.train_unsupervised('para.txt',model = "skipgram")

# %%
print(data.get_nearest_neighbors("learning"))
# Out:
# [(0.19227886199951172, 'data'), (0.13809873163700104, 'helps'), (0.13138523697853088, 'text'), (0.1164960116147995, 'of'), (0.11629129201173782, 'machine'), (0.098421610891819, 'are'), (0.09355238825082779, 'in'), (0.09264703094959259, 'for'), (0.08051501214504242, 'and'), (0.05103681609034538, 'used')]

# %%
print(model.get_word_vector("machine"))
# Out:
# [ 8.1811886e-05  3.7517873e-04  5.6723674e-04 -5.3487648e-04
#   1.7060636e-04  3.4931887e-04  5.2740623e-04  2.7336302e-04
#  -3.2303750e-04  3.2573770e-04  4.5847610e-05  1.7622410e-04
#   1.6139864e-05 -3.9019799e-04 -2.4998229e-04 -5.8769376e-05
#  -7.5240961e-05  2.5438462e-04  1.1126072e-03 -5.2877510e-04
#   1.3602396e-03 -2.2216239e-04 -4.5304823e-05  5.0364499e-05
#  -1.0998168e-03 -2.6891110e-04  5.0525926e-04 -1.0117027e-04
#  -2.3246810e-04 -8.3611958e-04  3.3943658e-04 -6.3759566e-04
#   6.3348294e-04 -2.0519242e-04 -1.1069955e-04 -7.9945824e-04
#   4.7523639e-04  9.1401125e-05 -3.6329959e-04  3.2377942e-04
#   2.0558735e-04  1.9708247e-04  1.0612421e-06 -3.3414611e-04
#   3.1215372e-05 -6.6138507e-04 -3.7588942e-04 -1.9545201e-05
#   2.5407400e-04  5.8538129e-04  8.5859833e-04  1.2271898e-03
#   2.9517149e-04 -2.1208575e-04  2.0074609e-04  4.9416663e-04
#  -1.3835770e-03  2.9795291e-04  1.8344645e-04 -1.4823201e-04
# ...

# %%
print(data.get_nearest_neighbors("learning"))
# Out:
# [(0.19227886199951172, 'data'), (0.13809873163700104, 'helps'), (0.13138523697853088, 'text'), (0.1164960116147995, 'of'), (0.11629129201173782, 'machine'), (0.098421610891819, 'are'), (0.09355238825082779, 'in'), (0.09264703094959259, 'for'), (0.08051501214504242, 'and'), (0.05103681609034538, 'used')]

# %%
data.get_words()
# Out:
# ['</s>',
#  'is',
#  'in',
#  'learning',
#  'for',
#  'AI',
#  'used',
#  'helps',
#  'and',
#  'of',
#  'data',
#  'machine',
#  'a',
#  'model',
#  'Machine',
#  'Data',
#  'data.',
#  'improves',
#  'are',
#  'text',
#  'language',
#  'FastText',
#  'uses',
#  'systems',
#  'to']

# %%
data.get_dimension()
# Out:
# 100

# %% [markdown]
# from imbd dataset choose a row and apply fasttext on it

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/IMDB Dataset - IMDB Dataset.csv")
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# Lowercase

df['review'] = df['review'].str.lower()
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. <br /><br />the...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %%
# remove url

import re

def remove_url(text):
  pattern = re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r'', text)

# %%
df['review'] = df['review'].apply(remove_url)
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. <br /><br />the...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %%
# Remove html tag

def remove_html_tag(text):
  pattern = re.compile('<.*?>')
  return pattern.sub(r'', text)

# %%
df['review']=df['review'].apply(remove_html_tag)

# %%
# 3. remove punctuation

import string
string.punctuation

exclude = string.punctuation

def remove_punc(text):
  for char in exclude:
    text = text.replace(char, '')
  return text

# %%
df['review'] = df['review'].apply(remove_punc)

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 42.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
x = df['review'][4]
x
# Out:
# 'petter matteis love in the time of money is a visually stunning film to watch mr mattei offers us a vivid portrait about human relations this is a movie that seems to be telling us what money power and success do to people in the different situations we encounter this being a variation on the arthur schnitzlers play about the same theme the director transfers the action to the present time new york where all these different characters meet and connect each one is connected in one way or another to the next person but no one seems to know the previous point of contact stylishly the film has a sophisticated luxurious look we are taken to see how these people live and the world they live in their own habitatthe only thing one gets out of all these souls in the picture is the different stages of loneliness each one inhabits a big city is not exactly the best place in which human relations find sincere fulfillment as one discerns is the case with most of the people we encounterthe acting
# ...

# %%
# NER
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp(x)

for token in doc.ents:
  print(token.text, "--->", token.label_)
# Out:
# new york ---> GPE
# one ---> CARDINAL
# one ---> CARDINAL
# one ---> CARDINAL
# steve ---> PERSON
# kane michael ---> PERSON
# imperioli adrian ---> ORG

# %%
from spacy import displacy
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">petter matteis love in the time of money is a visually stunning film to watch mr mattei offers us a vivid portrait about human relations this is a movie that seems to be telling us what money power and success do to people in the different situations we encounter this being a variation on the arthur schnitzlers play about the same theme the director transfers the action to the present time
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  where all these different characters meet and connect each one is connected in
# ...

# %%
# post tagging'

import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(x)

for token in doc:
  print(token.text,"-->",token.pos_)
# Out:
# petter --> NOUN
# matteis --> PROPN
# love --> NOUN
# in --> ADP
# the --> DET
# time --> NOUN
# of --> ADP
# money --> NOUN
# is --> AUX
# a --> DET
# visually --> ADV
# stunning --> ADJ
# film --> NOUN
# to --> PART
# watch --> VERB
# mr --> PROPN
# mattei --> NOUN
# offers --> VERB
# us --> PRON
# a --> DET
# vivid --> ADJ
# portrait --> NOUN
# about --> ADP
# human --> ADJ
# relations --> NOUN
# this --> PRON
# is --> AUX
# a --> DET
# movie --> NOUN
# that --> PRON
# seems --> VERB
# to --> PART
# be --> AUX
# telling --> VERB
# us --> PRON
# what --> PRON
# money --> NOUN
# power --> NOUN
# and --> CCONJ
# success --> NOUN
# do --> VERB
# to --> ADP
# people --> NOUN
# in --> ADP
# the --> DET
# different --> ADJ
# situations --> NOUN
# we --> PRON
# encounter --> VERB
# this --> PRON
# being --> AUX
# a --> DET
# variation --> NOUN
# on --> ADP
# the --> DET
# arthur --> PROPN
# schnitzlers --> NOUN
# play --> VERB
# about --> ADP
# the --> DET
# same --> ADJ
# theme --> NOUN
# ...

# %%
# Fasttext

# %%
import fasttext

# %%
x
# Out:
# 'petter matteis love in the time of money is a visually stunning film to watch mr mattei offers us a vivid portrait about human relations this is a movie that seems to be telling us what money power and success do to people in the different situations we encounter this being a variation on the arthur schnitzlers play about the same theme the director transfers the action to the present time new york where all these different characters meet and connect each one is connected in one way or another to the next person but no one seems to know the previous point of contact stylishly the film has a sophisticated luxurious look we are taken to see how these people live and the world they live in their own habitatthe only thing one gets out of all these souls in the picture is the different stages of loneliness each one inhabits a big city is not exactly the best place in which human relations find sincere fulfillment as one discerns is the case with most of the people we encounterthe acting
# ...

# %%
with open("new.txt","w") as f:
  f.write(x)

# %%
one = fasttext.train_unsupervised("new.txt",model = "skipgram")

# %%
one.get_word_vector("family")
# Out:
# array([ 1.61663382e-04,  1.85052249e-05, -6.86003594e-04,  2.50368845e-04,
#        -1.44325939e-04,  1.46333419e-04,  3.16273596e-04, -9.51737675e-05,
#        -4.18820477e-04, -4.39156254e-04,  2.47959688e-04, -3.08098359e-04,
#        -3.33726581e-04,  2.75753937e-05, -8.63808964e-04, -8.50313925e-04,
#         5.64638816e-04, -2.46341689e-04,  2.91605276e-04,  4.84101620e-04,
#        -3.58046964e-05, -3.31535307e-06,  4.05310653e-04,  2.64434842e-04,
#        -9.20722596e-05,  3.36441415e-04, -7.44309873e-05, -1.26446961e-04,
#        -3.25256115e-04,  1.90225866e-04, -1.44204576e-04,  2.63943715e-04,
#         3.87226792e-05,  9.02845568e-05, -7.81682611e-04, -8.66968709e-04,
#        -3.55299562e-07, -9.41633130e-04, -7.29159510e-04,  1.33638227e-04,
#         1.99159840e-05, -9.13142459e-04, -6.66094129e-04,  5.38277673e-04,
#        -4.23485384e-04, -6.81237434e-04, -4.33591253e-04, -4.63037868e-04,
# ...

# %%
one.get_nearest_neighbors("family")
# Out:
# [(0.17851106822490692, 'a'),
#  (0.021792469546198845, 'the'),
#  (-0.02371860295534134, 'to'),
#  (-0.03515170142054558, 'of'),
#  (-0.04095827043056488, 'in'),
#  (-0.06647736579179764, 'one'),
#  (-0.10409974306821823, 'and'),
#  (-0.15333291888237, 'is')]

# %%
one.get_words()
# Out:
# ['the', 'to', 'is', 'in', 'of', 'a', 'one', 'and']

# %%
one.get_dimension()
# Out:
# 100
