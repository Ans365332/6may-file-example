# %% [markdown]
# <a href="https://colab.research.google.com/github/Ans365332/6may-file-example/blob/main/Panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas-->
#-It is a python library which is used for the data manipulation.

# %%
import pandas as pd

# %%
###-->Series is basically a 1d array /labelled array
pd.Series([1,2,3,4],index=['a','b','c','d'])
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
#Creating serie data structure using dictionary
pd.Series({'a':1,'b':2,'c':3,'d':4})
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
### Data frame is basically 2d labelled data(table)
data={
    'Name':['a','b','c','d'],
    'Age':[1,2,3,4],
    'city':['aa','bb','cc','dd']
}
df=pd.DataFrame(data)
df
# Out:
#   Name  Age city
# 0    a    1   aa
# 1    b    2   bb
# 2    c    3   cc
# 3    d    4   dd

# %%
df.head(2)  #For accessig the first 2 rows we can give 2 in paranthesis otherwise
#it will print first five rows
# Out:
#   Name  Age city
# 0    a    1   aa
# 1    b    2   bb

# %%
df.shape
# Out:
# (4, 3)

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# city    object
# dtype: object

# %%
# for last five
df.tail(2)
# Out:
#   Name  Age city
# 2    c    3   cc
# 3    d    4   dd

# %%
# for columns
df.columns
# Out:
# Index(['Name', 'Age', 'city'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   city    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#             Age
# count  4.000000
# mean   2.500000
# std    1.290994
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.250000
# max    4.000000

# %%
# access particular row-->
df['Age']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: Age, dtype: int64

# %%
df['Age'].isna().sum()  #count null values
# Out:
# np.int64(0)

# %%
df.select_dtypes(include='object')
# Out:
#   Name city
# 0    a   aa
# 1    b   bb
# 2    c   cc
# 3    d   dd

# %%
df.select_dtypes(include=int)
# Out:
#    Age
# 0    1
# 1    2
# 2    3
# 3    4

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     0
# city    0
# dtype: int64
