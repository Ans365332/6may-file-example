# %% [markdown]
# <a href="https://colab.research.google.com/github/Ans365332/6may-file-example/blob/main/Apriori_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/market_basket - market_basket.csv',header= None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
df.shape
# Out:
# (7501, 20)

# %%
# !pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=de9b7b8cafdccb57f16eec5b4ba0d0b254edb90e06649bc152f1c16c84365e1c
#   Stored in directory: /root/.cache/pip/wheels/7f/49/e3/42c73b19a264de37129fadaa0c52f26cf50e87de08fb9804af
# Successfully built apyori
# ...

# %%
# Data processing
transactions=[]
for i in range(0,7501):
  transactions.append([str(df.values[i,j]) for j in range(0,20)])


# Training the dataset
from apyori import apriori
rules=apriori(transactions=transactions,
              min_support=0.003,  #(3 items* 7 days in week)/(total rows in dataset 7501)
              min_confidence=0.2,
              min_lift=3,
              min_length=2)

# Visualizing the results
a=list(rules)
result=[list(a[i][0]) for i in range(0,len(a))]

# %%
#a  # it is in json format now we convert it in list

# %%
result
# Out:
# [['light cream', 'chicken'],
#  ['escalope', 'mushroom cream sauce'],
#  ['pasta', 'escalope'],
#  ['honey', 'fromage blanc'],
#  ['herb & pepper', 'ground beef'],
#  ['ground beef', 'tomato sauce'],
#  ['light cream', 'olive oil'],
#  ['whole wheat pasta', 'olive oil'],
#  ['shrimp', 'pasta'],
#  ['avocado', 'milk', 'spaghetti'],
#  ['cake', 'burgers', 'milk'],
#  ['chocolate', 'burgers', 'turkey'],
#  ['burgers', 'milk', 'turkey'],
#  ['cake', 'tomatoes', 'frozen vegetables'],
#  ['cereals', 'ground beef', 'spaghetti'],
#  ['ground beef', 'chicken', 'milk'],
#  ['light cream', 'nan', 'chicken'],
#  ['olive oil', 'chicken', 'milk'],
#  ['olive oil', 'chicken', 'spaghetti'],
#  ['shrimp', 'chocolate', 'frozen vegetables'],
#  ['herb & pepper', 'chocolate', 'ground beef'],
#  ['soup', 'chocolate', 'milk'],
#  ['cooking oil', 'ground beef', 'spaghetti'],
#  ['herb & pepper', 'ground beef', 'eggs'],
#  ['spaghetti', 'red wine', 'eggs'],
#  ['nan', 'escalope', 'mushroom cream sauce'],
# ...
