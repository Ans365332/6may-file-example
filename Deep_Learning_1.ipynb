# %% [markdown]
# <a href="https://colab.research.google.com/github/Ans365332/6may-file-example/blob/main/Deep_Learning_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Introduction to deep Learning --->

# work based on human nervous system --> works on neuron --> inspired -->
# Artificial neural network


# ML--> When we have less complex data
# DL ---> When we have more complex data

# %%
# .(x11)

      #  .(x21)

# .(x12)           .(x31) -----> output(y)

#       .(x22)

#.(x13)

# %%
# x11  --> x21 ---> x31 ---> y (forward propagation)
# y --> x31 --> x21 ---> x11 (Backward Propagation)

# %%
# chain rule -->

# dy/dx11 = (dy/dx31 * dx31/dx21 * dx21/dx11) + (dy/dx31 * dx31/dx22 * dx22/dx11)

# dy/dx12 = (dy/dx31 * dx31/dx21 * dx21/dx12)  + (dy/dx31 * dx31/dx22 * dx22/dx12)

# dy/dx13 = (dy/dx31 * dx31/dx21 * dx21/dx13) + (dy/dx31 * dx31/dx22 * dx22/dx13)

# %%
# Workflow of ML

# Data Ingestion --> Data Preprocessing --> Select Ml model --> train the model --->
# prediction --> calculate accuracy

# %%
# workflow of dl

# data ingestion ---> data cleaning and preprocessing -->

# Create a model sequential
# input_layer (input_columns,neurons,Activation_function)
# hidden_layer (neurons,Activation_function)
# output_layer (neurons based on target column,Activation_function)

# model.compile(loss_fn, optiizer , metrics)

# model.training

# model.prediction

# model total loss and total accuracy

# %%
# Loss function --> it is the distance between actual and predicted point.

# (1.) When we have 2 sub-categories in target column,then we will use 'binary_cross_entropy' as
# an loss function.

# (2.) When we have more than 2 sub-categories in target column,then we will use 'sparse_categorical_cross_entropy'

# (3.) When we have numerical target column then we will use 'mean_squared_error','mean_absolute_error' as loss function.

# %%
# Optimization techique in Ml -->

# (1). Gradient Descent ---> Entire data respect ---> y = m_new * X+b_new

# (2). Stocastic Gradient Descent ---> In this ,we will select only a random row then we will calculate
# y = m_new * X+b_new

# (3). Mini Batch Gradient Descent ---> In this ,we select our data in batches then we will calculate
# Ex- If we have 100 rows then
# A Batch = 25
# B Batch = 25
# C Batch = 25
# D Batch = 25


# We will select a random batch using numpy random module.
# Let suppose if we have B batch ,then we in this batch total 25 rows are (x) and
# their columns are m or weights. so using this data,it will reduce the loss function
# and find the best y= m_new * X+b_new
