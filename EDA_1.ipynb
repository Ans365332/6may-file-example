# %% [markdown]
# <a href="https://colab.research.google.com/github/Ans365332/6may-file-example/blob/main/EDA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA-->(Exploratory data analysis)
# 1-univariant analysis
#
# 2.bivariant analysis
#
# 3.multivariant analysis

# %%
# Data Cleaning

# %%
# Univarient analysis-(it is done on single features)
#histplot,countplot,boxplot

# %%
# Bivariant analysis
# scatter plot,line plot,barplot,boxplot

# %%
# Multivariant analysis
# heatmap , kde plot ,pairplot

# %% [markdown]
# #Table of Contents
# Data Loading & Initial Exploration
#
# Import necessary libraries
# Load the dataset
# Basic dataset information
# First look at the data
# Data Cleaning & Preprocessing
#
# Handle missing values
# Data type conversions
# Remove duplicates
# Handle outliers
# Univariate Analysis
#
# App categories distribution
# Ratings analysis
# Price distribution
# App size analysis
# Content rating distribution
# Bivariate Analysis
#
# Category vs Rating
# Price vs Downloads
# Size vs Rating
# Reviews vs Rating
# Multivariate Analysis
#
# Category, Price, and Rating relationships
# Advanced correlation analysis
# Feature interactions
# Market Insights
#
# Top apps by category
# Free vs Paid apps analysis
# Market trends
# Success factors
# Visualizations
#
# Interactive plots
# Statistical charts
# Trend analysis graphs
# Conclusions & Recommendations
#
# Key findings summary
# Business recommendations
# Future analysis suggestions

# %%
# Data exploration and data cleaning

# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data loading and data exploration

df=pd.read_csv('/content/googleplaystore (1) - googleplaystore (1).csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Exploring first five row
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Exploring last five row
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# random row
df.sample(5)
# Out:
#                               App          Category  Rating Reviews  \
# 379                 My Vodacom SA     COMMUNICATION     3.7   25021
# 2539  Low Blood Pressure Symptoms           MEDICAL     4.2      28
# 3228    Geo Tracker - GPS tracker  TRAVEL_AND_LOCAL     4.5   42849
# 856       Complete Spanish Movies     ENTERTAINMENT     4.0   11656
# 5654                  Au Bon Pain    FOOD_AND_DRINK     3.7      70
#
#                     Size    Installs  Type Price Content Rating  \
# 379                  61M  5,000,000+  Free     0       Everyone
# 2539                2.3M     10,000+  Free     0       Everyone
# 3228  Varies with device  1,000,000+  Free     0       Everyone
# 856                 4.5M  1,000,000+  Free     0       Everyone
# 5654                 26M     10,000+  Free     0       Everyone
#
#               Genres      Last Updated         Current Ver         Android Ver
# 379    Communication     June 26, 2018               9.9.0          4.3 and up
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# # data Data Cleaning & Preprocessing

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# for rating-->

df['Rating'].dtype
# Out:
# dtype('float64')

# %%
# Since the rating column is numerical column so we check the outlyer

sns.boxplot(x=df['Rating'],data=df)
# Out:
# <Axes: xlabel='Rating'>

# %%
# Imputing the rating column with the median because there are many outliers
#are present that column

df['Rating'].fillna(df['Rating'].median(),inplace=True)
# Out:
# /tmp/ipython-input-3057256991.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rating'].fillna(df['Rating'].median(),inplace=True)

# %%
df['Rating'].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
df['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
df['Type'].fillna(df['Type'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-3627273287.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Type'].fillna(df['Type'].mode()[0],inplace=True)

# %%
df['Type'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           8714
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
df['Content Rating'].fillna(df['Content Rating'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-1853723298.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Content Rating'].fillna(df['Content Rating'].mode()[0],inplace=True)

# %%
df['Content Rating'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Current Ver'].value_counts()
# Out:
# Current Ver
# Varies with device    1459
# 1                      842
# 1.1                    276
# 1.2                    185
# 2                      165
#                       ...
# 4.5.9                    1
# 4.6.1404                 1
# v4.30.0.9                1
# 2.1.9f7                  1
# 1.9.734                  1
# Name: count, Length: 2784, dtype: int64

# %%
df['Current Ver'].fillna(df['Current Ver'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-2644594430.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Current Ver'].fillna(df['Current Ver'].mode()[0],inplace=True)

# %%
df['Current Ver'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Android Ver'].value_counts()
# Out:
# Android Ver
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 5.0 - 8.0                2
# 4.0.3 - 7.1.1            2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: count, dtype: int64

# %%
df['Android Ver'].fillna(df['Android Ver'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-2559972690.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Android Ver'].fillna(df['Android Ver'].mode()[0],inplace=True)

# %%
df['Android Ver'].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10841 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10841 non-null  object
#  12  Android Ver     10841 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# to change datatype
df['Rewievs']=df['Reviews'].astype(int)

# %% [markdown]
# it cant be change beacause a string value present in it

# %%
df['Reviews']=pd.to_numeric(df['Reviews'],errors='coerce')

# %%
df['Reviews'].dtypes
# Out:
# dtype('float64')
